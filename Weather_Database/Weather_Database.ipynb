# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90,90,size=2000)
lngs = np.random.uniform(-180,180,size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call


url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
#import the time module
import time
# Get today's date in seconds.




# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        
        city_weather = requests.get(city_url).json()
        
        
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description":city_description,
                          "Date": city_date})
        
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 1 | barrow
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | fairbanks
# Processing Record 5 of Set 1 | baruun-urt
# Processing Record 6 of Set 1 | elizabeth city
# Processing Record 7 of Set 1 | bambous virieux
# Processing Record 8 of Set 1 | feijo
# Processing Record 9 of Set 1 | tazlau
# Processing Record 10 of Set 1 | tasiilaq
# Processing Record 11 of Set 1 | lagos
# Processing Record 12 of Set 1 | kodiak
# Processing Record 13 of Set 1 | seminole
# Processing Record 14 of Set 1 | moron
# Processing Record 15 of Set 1 | idritsa
# Processing Record 16 of Set 1 | hilo
# Processing Record 17 of Set 1 | arraial do cabo
# Processing Record 18 of Set 1 | airai
# Processing Record 19 of Set 1 | cayenne
# Processing Record 20 of Set 1 | bonthe
# Processing Record 21 of Set 1 | sao joao da barra
# Processing Record 22 of Set 1 | panguna
# Processing Record 23 of Set 1 | butaritari
# Processing Record 24 of Set 1 | balimo
# City not found. Skipping...
# Processing Record 25 of Set 1 | cozumel
# Processing Record 26 of Set 1 | qaanaaq
# Processing Record 27 of Set 1 | saskylakh
# Processing Record 28 of Set 1 | atuona
# Processing Record 29 of Set 1 | vaini
# Processing Record 30 of Set 1 | hobart
# Processing Record 31 of Set 1 | bluff
# Processing Record 32 of Set 1 | upernavik
# Processing Record 33 of Set 1 | bonavista
# Processing Record 34 of Set 1 | wulanhaote
# City not found. Skipping...
# Processing Record 35 of Set 1 | nikolskoye
# Processing Record 36 of Set 1 | punta arenas
# Processing Record 37 of Set 1 | albany
# Processing Record 38 of Set 1 | mataura
# Processing Record 39 of Set 1 | bredasdorp
# Processing Record 40 of Set 1 | mar del plata
# Processing Record 41 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 42 of Set 1 | ushuaia
# Processing Record 43 of Set 1 | tiksi
# Processing Record 44 of Set 1 | kutum
# Processing Record 45 of Set 1 | sao jose da coroa grande
# Processing Record 46 of Set 1 | talnakh
# Processing Record 47 of Set 1 | hermanus
# Processing Record 48 of Set 1 | puerto ayora
# Processing Record 49 of Set 1 | bahia honda
# Processing Record 50 of Set 1 | grand gaube
# Processing Record 1 of Set 2 | vrangel
# Processing Record 2 of Set 2 | iwanai
# Processing Record 3 of Set 2 | baoshan
# Processing Record 4 of Set 2 | okhotsk
# Processing Record 5 of Set 2 | waingapu
# Processing Record 6 of Set 2 | dingle
# Processing Record 7 of Set 2 | castro
# Processing Record 8 of Set 2 | bismarck
# Processing Record 9 of Set 2 | pevek
# Processing Record 10 of Set 2 | belaya gora
# Processing Record 11 of Set 2 | cherskiy
# Processing Record 12 of Set 2 | kavaratti
# Processing Record 13 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 14 of Set 2 | souillac
# Processing Record 15 of Set 2 | coxim
# Processing Record 16 of Set 2 | naze
# Processing Record 17 of Set 2 | vardo
# Processing Record 18 of Set 2 | carnarvon
# Processing Record 19 of Set 2 | pakxe
# Processing Record 20 of Set 2 | altamont
# Processing Record 21 of Set 2 | comodoro rivadavia
# Processing Record 22 of Set 2 | busselton
# Processing Record 23 of Set 2 | lagoa
# Processing Record 24 of Set 2 | chushan
# Processing Record 25 of Set 2 | sao filipe
# Processing Record 26 of Set 2 | portsmouth
# Processing Record 27 of Set 2 | espanola
# Processing Record 28 of Set 2 | port elizabeth
# Processing Record 29 of Set 2 | nelson bay
# Processing Record 30 of Set 2 | rennes
# Processing Record 31 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 2 | cunha
# Processing Record 33 of Set 2 | severo-kurilsk
# Processing Record 34 of Set 2 | lerik
# Processing Record 35 of Set 2 | san quintin
# Processing Record 36 of Set 2 | avarua
# Processing Record 37 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 38 of Set 2 | aykhal
# Processing Record 39 of Set 2 | pitimbu
# Processing Record 40 of Set 2 | khatanga
# Processing Record 41 of Set 2 | bay roberts
# Processing Record 42 of Set 2 | longyearbyen
# Processing Record 43 of Set 2 | dali
# Processing Record 44 of Set 2 | yellowknife
# Processing Record 45 of Set 2 | tuktoyaktuk
# Processing Record 46 of Set 2 | vaitape
# Processing Record 47 of Set 2 | laguna
# Processing Record 48 of Set 2 | ostersund
# Processing Record 49 of Set 2 | paamiut
# Processing Record 50 of Set 2 | pangkalanbuun
# Processing Record 1 of Set 3 | kongolo
# Processing Record 2 of Set 3 | kindu
# Processing Record 3 of Set 3 | toora-khem
# Processing Record 4 of Set 3 | sitka
# Processing Record 5 of Set 3 | kapaa
# Processing Record 6 of Set 3 | ribeira grande
# Processing Record 7 of Set 3 | port hedland
# Processing Record 8 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 9 of Set 3 | port alfred
# Processing Record 10 of Set 3 | nuevo ideal
# Processing Record 11 of Set 3 | sterling
# Processing Record 12 of Set 3 | mandan
# Processing Record 13 of Set 3 | kieta
# Processing Record 14 of Set 3 | san pedro
# Processing Record 15 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 16 of Set 3 | isabela
# Processing Record 17 of Set 3 | batemans bay
# Processing Record 18 of Set 3 | malanje
# Processing Record 19 of Set 3 | asyut
# Processing Record 20 of Set 3 | muromtsevo
# Processing Record 21 of Set 3 | cape town
# Processing Record 22 of Set 3 | wembley
# Processing Record 23 of Set 3 | coquimbo
# Processing Record 24 of Set 3 | waipawa
# Processing Record 25 of Set 3 | nome
# Processing Record 26 of Set 3 | kautokeino
# Processing Record 27 of Set 3 | sisimiut
# Processing Record 28 of Set 3 | guajara-mirim
# City not found. Skipping...
# Processing Record 29 of Set 3 | yar-sale
# Processing Record 30 of Set 3 | lysyye gory
# Processing Record 31 of Set 3 | provideniya
# Processing Record 32 of Set 3 | zheleznodorozhnyy
# Processing Record 33 of Set 3 | ayan
# Processing Record 34 of Set 3 | georgetown
# Processing Record 35 of Set 3 | vestmannaeyjar
# Processing Record 36 of Set 3 | kangaatsiaq
# Processing Record 37 of Set 3 | thompson
# Processing Record 38 of Set 3 | lorengau
# Processing Record 39 of Set 3 | los llanos de aridane
# Processing Record 40 of Set 3 | salalah
# Processing Record 41 of Set 3 | esperance
# Processing Record 42 of Set 3 | galich
# Processing Record 43 of Set 3 | nouadhibou
# Processing Record 44 of Set 3 | zavallya
# Processing Record 45 of Set 3 | ratnagiri
# Processing Record 46 of Set 3 | tura
# Processing Record 47 of Set 3 | cidreira
# Processing Record 48 of Set 3 | taunggyi
# Processing Record 49 of Set 3 | yabelo
# Processing Record 50 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 4 | bur gabo
# City not found. Skipping...
# Processing Record 2 of Set 4 | kaitangata
# Processing Record 3 of Set 4 | shenjiamen
# Processing Record 4 of Set 4 | lasa
# Processing Record 5 of Set 4 | kalmunai
# Processing Record 6 of Set 4 | pisco
# Processing Record 7 of Set 4 | margate
# Processing Record 8 of Set 4 | tidore
# City not found. Skipping...
# Processing Record 9 of Set 4 | hithadhoo
# Processing Record 10 of Set 4 | acatlan
# Processing Record 11 of Set 4 | chancay
# Processing Record 12 of Set 4 | lebu
# Processing Record 13 of Set 4 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 14 of Set 4 | riyadh
# Processing Record 15 of Set 4 | harrismith
# Processing Record 16 of Set 4 | port hardy
# Processing Record 17 of Set 4 | new norfolk
# Processing Record 18 of Set 4 | geresk
# City not found. Skipping...
# Processing Record 19 of Set 4 | melnikovo
# Processing Record 20 of Set 4 | college
# Processing Record 21 of Set 4 | saint-philippe
# Processing Record 22 of Set 4 | bethel
# Processing Record 23 of Set 4 | kenai
# Processing Record 24 of Set 4 | jamestown
# Processing Record 25 of Set 4 | faanui
# Processing Record 26 of Set 4 | sakakah
# Processing Record 27 of Set 4 | litovko
# Processing Record 28 of Set 4 | san patricio
# Processing Record 29 of Set 4 | mitsamiouli
# Processing Record 30 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 31 of Set 4 | kafue
# Processing Record 32 of Set 4 | rudnogorsk
# Processing Record 33 of Set 4 | harper
# Processing Record 34 of Set 4 | victoria
# Processing Record 35 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 36 of Set 4 | aberdeen
# Processing Record 37 of Set 4 | atyrau
# Processing Record 38 of Set 4 | hosdurga
# Processing Record 39 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 40 of Set 4 | salinopolis
# Processing Record 41 of Set 4 | berlevag
# Processing Record 42 of Set 4 | borovoy
# Processing Record 43 of Set 4 | kuala terengganu
# Processing Record 44 of Set 4 | tigil
# Processing Record 45 of Set 4 | kavieng
# Processing Record 46 of Set 4 | oriximina
# Processing Record 47 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 4 | aklavik
# Processing Record 49 of Set 4 | oslo
# Processing Record 50 of Set 4 | gilgit
# Processing Record 1 of Set 5 | lata
# Processing Record 2 of Set 5 | orodara
# Processing Record 3 of Set 5 | ati
# Processing Record 4 of Set 5 | bonfim
# Processing Record 5 of Set 5 | dubovskoye
# Processing Record 6 of Set 5 | cochrane
# Processing Record 7 of Set 5 | clemmons
# Processing Record 8 of Set 5 | bengkalis
# City not found. Skipping...
# Processing Record 9 of Set 5 | port hawkesbury
# Processing Record 10 of Set 5 | kanigoro
# Processing Record 11 of Set 5 | cocorit
# Processing Record 12 of Set 5 | katsuura
# Processing Record 13 of Set 5 | hofn
# Processing Record 14 of Set 5 | dawei
# Processing Record 15 of Set 5 | alghero
# Processing Record 16 of Set 5 | hasaki
# Processing Record 17 of Set 5 | sorland
# Processing Record 18 of Set 5 | ulladulla
# Processing Record 19 of Set 5 | yulara
# Processing Record 20 of Set 5 | rosarito
# Processing Record 21 of Set 5 | coahuayana
# Processing Record 22 of Set 5 | grindavik
# Processing Record 23 of Set 5 | vanavara
# Processing Record 24 of Set 5 | nemuro
# Processing Record 25 of Set 5 | balangiga
# Processing Record 26 of Set 5 | walvis bay
# Processing Record 27 of Set 5 | praia da vitoria
# Processing Record 28 of Set 5 | dikson
# Processing Record 29 of Set 5 | port-gentil
# Processing Record 30 of Set 5 | galgani
# City not found. Skipping...
# Processing Record 31 of Set 5 | butembo
# Processing Record 32 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 33 of Set 5 | ilulissat
# Processing Record 34 of Set 5 | kawalu
# Processing Record 35 of Set 5 | yenagoa
# Processing Record 36 of Set 5 | humaita
# Processing Record 37 of Set 5 | ostrovnoy
# Processing Record 38 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 39 of Set 5 | cabedelo
# Processing Record 40 of Set 5 | kaupanger
# Processing Record 41 of Set 5 | evanston
# Processing Record 42 of Set 5 | havoysund
# Processing Record 43 of Set 5 | gagret
# Processing Record 44 of Set 5 | saldanha
# Processing Record 45 of Set 5 | north bend
# Processing Record 46 of Set 5 | torbay
# Processing Record 47 of Set 5 | port augusta
# Processing Record 48 of Set 5 | geraldton
# Processing Record 49 of Set 5 | rexburg
# Processing Record 50 of Set 5 | byron bay
# Processing Record 1 of Set 6 | niamey
# Processing Record 2 of Set 6 | bud
# Processing Record 3 of Set 6 | puerto del rosario
# Processing Record 4 of Set 6 | kahului
# Processing Record 5 of Set 6 | arinos
# Processing Record 6 of Set 6 | porbandar
# Processing Record 7 of Set 6 | east london
# Processing Record 8 of Set 6 | opuwo
# Processing Record 9 of Set 6 | lapithos
# Processing Record 10 of Set 6 | abbeville
# Processing Record 11 of Set 6 | verkhnyaya inta
# Processing Record 12 of Set 6 | tautira
# Processing Record 13 of Set 6 | baturaja
# Processing Record 14 of Set 6 | mahebourg
# Processing Record 15 of Set 6 | egvekinot
# Processing Record 16 of Set 6 | worth
# Processing Record 17 of Set 6 | asfi
# Processing Record 18 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 19 of Set 6 | ponta do sol
# Processing Record 20 of Set 6 | nanortalik
# Processing Record 21 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 22 of Set 6 | havelock
# Processing Record 23 of Set 6 | mange
# Processing Record 24 of Set 6 | tonekabon
# Processing Record 25 of Set 6 | brewster
# Processing Record 26 of Set 6 | camana
# Processing Record 27 of Set 6 | mizdah
# Processing Record 28 of Set 6 | saint-paul
# Processing Record 29 of Set 6 | san cristobal
# Processing Record 30 of Set 6 | puerto colombia
# Processing Record 31 of Set 6 | codrington
# Processing Record 32 of Set 6 | angoche
# Processing Record 33 of Set 6 | meulaboh
# Processing Record 34 of Set 6 | isangel
# Processing Record 35 of Set 6 | faya
# Processing Record 36 of Set 6 | beihai
# Processing Record 37 of Set 6 | ngawen
# Processing Record 38 of Set 6 | izumo
# Processing Record 39 of Set 6 | la esperanza
# Processing Record 40 of Set 6 | komsomolskiy
# Processing Record 41 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 42 of Set 6 | matara
# Processing Record 43 of Set 6 | asau
# Processing Record 44 of Set 6 | haibowan
# City not found. Skipping...
# Processing Record 45 of Set 6 | roseburg
# Processing Record 46 of Set 6 | kisangani
# Processing Record 47 of Set 6 | sambava
# Processing Record 48 of Set 6 | lavrentiya
# Processing Record 49 of Set 6 | bollnas
# Processing Record 50 of Set 6 | hambantota
# Processing Record 1 of Set 7 | whitehorse
# Processing Record 2 of Set 7 | denton
# Processing Record 3 of Set 7 | altay
# Processing Record 4 of Set 7 | campos belos
# Processing Record 5 of Set 7 | tazovskiy
# Processing Record 6 of Set 7 | dubbo
# Processing Record 7 of Set 7 | mahibadhoo
# Processing Record 8 of Set 7 | erzin
# Processing Record 9 of Set 7 | gazanjyk
# Processing Record 10 of Set 7 | constitucion
# Processing Record 11 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 7 | fallon
# Processing Record 13 of Set 7 | namibe
# Processing Record 14 of Set 7 | phonhong
# Processing Record 15 of Set 7 | batagay
# Processing Record 16 of Set 7 | paraiso
# Processing Record 17 of Set 7 | bar harbor
# Processing Record 18 of Set 7 | roald
# Processing Record 19 of Set 7 | marolambo
# Processing Record 20 of Set 7 | puerto suarez
# Processing Record 21 of Set 7 | ucluelet
# Processing Record 22 of Set 7 | murgab
# Processing Record 23 of Set 7 | lexington
# Processing Record 24 of Set 7 | sinnai
# Processing Record 25 of Set 7 | hyeres
# Processing Record 26 of Set 7 | gamba
# Processing Record 27 of Set 7 | norden
# Processing Record 28 of Set 7 | bilibino
# Processing Record 29 of Set 7 | sinnamary
# Processing Record 30 of Set 7 | sao domingos do maranhao
# Processing Record 31 of Set 7 | green river
# Processing Record 32 of Set 7 | lazaro cardenas
# Processing Record 33 of Set 7 | huicheng
# Processing Record 34 of Set 7 | george
# Processing Record 35 of Set 7 | chokurdakh
# Processing Record 36 of Set 7 | zhuanghe
# Processing Record 37 of Set 7 | saint-francois
# Processing Record 38 of Set 7 | puri
# Processing Record 39 of Set 7 | manali
# Processing Record 40 of Set 7 | hovd
# Processing Record 41 of Set 7 | oussouye
# Processing Record 42 of Set 7 | jinka
# Processing Record 43 of Set 7 | mumford
# Processing Record 44 of Set 7 | khovu-aksy
# Processing Record 45 of Set 7 | tabursuq
# Processing Record 46 of Set 7 | vallenar
# Processing Record 47 of Set 7 | jalu
# Processing Record 48 of Set 7 | karratha
# Processing Record 49 of Set 7 | saint-augustin
# Processing Record 50 of Set 7 | black river
# Processing Record 1 of Set 8 | shelburne
# Processing Record 2 of Set 8 | camacha
# Processing Record 3 of Set 8 | bubaque
# Processing Record 4 of Set 8 | avera
# Processing Record 5 of Set 8 | charters towers
# Processing Record 6 of Set 8 | taoudenni
# Processing Record 7 of Set 8 | desbiens
# Processing Record 8 of Set 8 | xichang
# Processing Record 9 of Set 8 | sal rei
# Processing Record 10 of Set 8 | alta floresta
# Processing Record 11 of Set 8 | akyab
# Processing Record 12 of Set 8 | ajdabiya
# Processing Record 13 of Set 8 | barroualie
# City not found. Skipping...
# Processing Record 14 of Set 8 | luganville
# Processing Record 15 of Set 8 | leningradskiy
# Processing Record 16 of Set 8 | staroye drozhzhanoye
# Processing Record 17 of Set 8 | stalpu
# Processing Record 18 of Set 8 | san antonio
# Processing Record 19 of Set 8 | biak
# Processing Record 20 of Set 8 | looc
# Processing Record 21 of Set 8 | hiroshima
# Processing Record 22 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 23 of Set 8 | acari
# Processing Record 24 of Set 8 | den helder
# Processing Record 25 of Set 8 | bengkulu
# Processing Record 26 of Set 8 | fort nelson
# Processing Record 27 of Set 8 | ilhabela
# Processing Record 28 of Set 8 | beloha
# Processing Record 29 of Set 8 | brenham
# Processing Record 30 of Set 8 | catuday
# Processing Record 31 of Set 8 | kruisfontein
# Processing Record 32 of Set 8 | bassano
# Processing Record 33 of Set 8 | aden
# Processing Record 34 of Set 8 | tiruvottiyur
# City not found. Skipping...
# Processing Record 35 of Set 8 | chuy
# Processing Record 36 of Set 8 | wurzburg
# Processing Record 37 of Set 8 | miramar
# Processing Record 38 of Set 8 | haradok
# Processing Record 39 of Set 8 | merrill
# Processing Record 40 of Set 8 | westport
# Processing Record 41 of Set 8 | gao
# Processing Record 42 of Set 8 | lompoc
# Processing Record 43 of Set 8 | jumla
# Processing Record 44 of Set 8 | noshiro
# Processing Record 45 of Set 8 | narsaq
# Processing Record 46 of Set 8 | jiaojiang
# Processing Record 47 of Set 8 | poltavka
# Processing Record 48 of Set 8 | ustka
# Processing Record 49 of Set 8 | kharan
# Processing Record 50 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 1 of Set 9 | dwarka
# Processing Record 2 of Set 9 | acajutla
# Processing Record 3 of Set 9 | saint george
# Processing Record 4 of Set 9 | swan hill
# Processing Record 5 of Set 9 | cabo san lucas
# Processing Record 6 of Set 9 | quchan
# Processing Record 7 of Set 9 | te anau
# Processing Record 8 of Set 9 | yunjinghong
# City not found. Skipping...
# Processing Record 9 of Set 9 | olafsvik
# Processing Record 10 of Set 9 | san juan
# Processing Record 11 of Set 9 | aguilas
# Processing Record 12 of Set 9 | chifeng
# Processing Record 13 of Set 9 | clyde river
# Processing Record 14 of Set 9 | bathsheba
# Processing Record 15 of Set 9 | berdigestyakh
# Processing Record 16 of Set 9 | kungalv
# Processing Record 17 of Set 9 | nioki
# Processing Record 18 of Set 9 | getahovit
# Processing Record 19 of Set 9 | hit
# Processing Record 20 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 21 of Set 9 | nuuk
# Processing Record 22 of Set 9 | guadalajara
# Processing Record 23 of Set 9 | beringovskiy
# Processing Record 24 of Set 9 | mezen
# Processing Record 25 of Set 9 | portland
# Processing Record 26 of Set 9 | innisfail
# Processing Record 27 of Set 9 | strezhevoy
# Processing Record 28 of Set 9 | peterhead
# Processing Record 29 of Set 9 | minot
# Processing Record 30 of Set 9 | abiy adi
# City not found. Skipping...
# Processing Record 31 of Set 9 | auki
# Processing Record 32 of Set 9 | ozernovskiy
# Processing Record 33 of Set 9 | iqaluit
# Processing Record 34 of Set 9 | samarai
# Processing Record 35 of Set 9 | maniitsoq
# Processing Record 36 of Set 9 | viransehir
# Processing Record 37 of Set 9 | inhambane
# Processing Record 38 of Set 9 | mogadishu
# Processing Record 39 of Set 9 | namatanai
# Processing Record 40 of Set 9 | inta
# Processing Record 41 of Set 9 | bajo baudo
# City not found. Skipping...
# Processing Record 42 of Set 9 | jimo
# Processing Record 43 of Set 9 | impfondo
# Processing Record 44 of Set 9 | ishinomaki
# Processing Record 45 of Set 9 | tabou
# Processing Record 46 of Set 9 | yumen
# Processing Record 47 of Set 9 | san nicolas
# Processing Record 48 of Set 9 | piacabucu
# Processing Record 49 of Set 9 | demak
# Processing Record 50 of Set 9 | port moresby
# Processing Record 1 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 2 of Set 10 | omboue
# Processing Record 3 of Set 10 | bereda
# Processing Record 4 of Set 10 | zwedru
# Processing Record 5 of Set 10 | muncar
# Processing Record 6 of Set 10 | anju
# Processing Record 7 of Set 10 | berbera
# Processing Record 8 of Set 10 | los andes
# Processing Record 9 of Set 10 | hamilton
# Processing Record 10 of Set 10 | adrar
# Processing Record 11 of Set 10 | vao
# Processing Record 12 of Set 10 | nagar karnul
# Processing Record 13 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 14 of Set 10 | suez
# Processing Record 15 of Set 10 | paracatu
# Processing Record 16 of Set 10 | sao felix do xingu
# Processing Record 17 of Set 10 | bokoro
# Processing Record 18 of Set 10 | kultuk
# Processing Record 19 of Set 10 | port macquarie
# Processing Record 20 of Set 10 | sangar
# Processing Record 21 of Set 10 | yerbogachen
# Processing Record 22 of Set 10 | somerset
# Processing Record 23 of Set 10 | jiangyou
# Processing Record 24 of Set 10 | wuda
# Processing Record 25 of Set 10 | safaga
# Processing Record 26 of Set 10 | le port
# Processing Record 27 of Set 10 | cubuk
# Processing Record 28 of Set 10 | goundam
# Processing Record 29 of Set 10 | aksarka
# Processing Record 30 of Set 10 | andenes
# Processing Record 31 of Set 10 | kodinar
# Processing Record 32 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 33 of Set 10 | honiara
# Processing Record 34 of Set 10 | araquari
# Processing Record 35 of Set 10 | tessalit
# Processing Record 36 of Set 10 | saint anthony
# Processing Record 37 of Set 10 | acarau
# Processing Record 38 of Set 10 | skalistyy
# City not found. Skipping...
# Processing Record 39 of Set 10 | braintree
# Processing Record 40 of Set 10 | temaraia
# City not found. Skipping...
# Processing Record 41 of Set 10 | aporawan
# City not found. Skipping...
# Processing Record 42 of Set 10 | paita
# Processing Record 43 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 44 of Set 10 | saku
# Processing Record 45 of Set 10 | weligama
# Processing Record 46 of Set 10 | xining
# Processing Record 47 of Set 10 | vitim
# Processing Record 48 of Set 10 | ugoofaaru
# Processing Record 49 of Set 10 | marzuq
# Processing Record 50 of Set 10 | mimongo
# Processing Record 1 of Set 11 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 2 of Set 11 | ye
# City not found. Skipping...
# Processing Record 3 of Set 11 | yala
# Processing Record 4 of Set 11 | sept-iles
# Processing Record 5 of Set 11 | kidal
# Processing Record 6 of Set 11 | kedrovyy
# Processing Record 7 of Set 11 | kurayoshi
# Processing Record 8 of Set 11 | husavik
# Processing Record 9 of Set 11 | chute-aux-outardes
# Processing Record 10 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 11 of Set 11 | banda aceh
# Processing Record 12 of Set 11 | maragogi
# Processing Record 13 of Set 11 | vila velha
# Processing Record 14 of Set 11 | tecoanapa
# Processing Record 15 of Set 11 | mykolayivka
# Processing Record 16 of Set 11 | shache
# Processing Record 17 of Set 11 | russell
# Processing Record 18 of Set 11 | chapais
# Processing Record 19 of Set 11 | flin flon
# Processing Record 20 of Set 11 | moshupa
# Processing Record 21 of Set 11 | along
# Processing Record 22 of Set 11 | alofi
# Processing Record 23 of Set 11 | sinkat
# City not found. Skipping...
# Processing Record 24 of Set 11 | blackwater
# Processing Record 25 of Set 11 | media luna
# Processing Record 26 of Set 11 | montepuez
# Processing Record 27 of Set 11 | linxia
# Processing Record 28 of Set 11 | siwani
# City not found. Skipping...
# Processing Record 29 of Set 11 | bambanglipuro
# Processing Record 30 of Set 11 | palana
# Processing Record 31 of Set 11 | rondonopolis
# Processing Record 32 of Set 11 | port blair
# Processing Record 33 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 34 of Set 11 | putnok
# Processing Record 35 of Set 11 | barkhan
# Processing Record 36 of Set 11 | umm kaddadah
# Processing Record 37 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 38 of Set 11 | minna
# Processing Record 39 of Set 11 | buckeburg
# Processing Record 40 of Set 11 | sfantu gheorghe
# Processing Record 41 of Set 11 | badnawar
# Processing Record 42 of Set 11 | arrifes
# Processing Record 43 of Set 11 | springdale
# Processing Record 44 of Set 11 | qaqortoq
# Processing Record 45 of Set 11 | chernyshevskiy
# Processing Record 46 of Set 11 | conceicao da barra
# Processing Record 47 of Set 11 | touros
# Processing Record 48 of Set 11 | baykit
# Processing Record 49 of Set 11 | kaeo
# Processing Record 50 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 1 of Set 12 | laem sing
# Processing Record 2 of Set 12 | sicamous
# Processing Record 3 of Set 12 | mullaitivu
# City not found. Skipping...
# Processing Record 4 of Set 12 | beira
# Processing Record 5 of Set 12 | tucurui
# Processing Record 6 of Set 12 | juegang
# Processing Record 7 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 8 of Set 12 | vieux-habitants
# Processing Record 9 of Set 12 | astaneh-ye ashrafiyeh
# Processing Record 10 of Set 12 | port lincoln
# Processing Record 11 of Set 12 | pierre
# Processing Record 12 of Set 12 | solovetskiy
# City not found. Skipping...
# Processing Record 13 of Set 12 | debre tabor
# Processing Record 14 of Set 12 | shiyan
# Processing Record 15 of Set 12 | ust-nera
# Processing Record 16 of Set 12 | aginskoye
# Processing Record 17 of Set 12 | ancud
# Processing Record 18 of Set 12 | vila franca do campo
# Processing Record 19 of Set 12 | necochea
# Processing Record 20 of Set 12 | bardiyah
# Processing Record 21 of Set 12 | eureka
# Processing Record 22 of Set 12 | luderitz
# Processing Record 23 of Set 12 | mount gambier
# Processing Record 24 of Set 12 | kenora
# Processing Record 25 of Set 12 | lundazi
# Processing Record 26 of Set 12 | mayumba
# Processing Record 27 of Set 12 | poum
# Processing Record 28 of Set 12 | sulphur
# Processing Record 29 of Set 12 | finschhafen
# Processing Record 30 of Set 12 | juneau
# Processing Record 31 of Set 12 | mporokoso
# Processing Record 32 of Set 12 | haines junction
# Processing Record 33 of Set 12 | hanyang
# Processing Record 34 of Set 12 | kuusamo
# Processing Record 35 of Set 12 | kattivakkam
# Processing Record 36 of Set 12 | hami
# Processing Record 37 of Set 12 | muisne
# Processing Record 38 of Set 12 | show low
# Processing Record 39 of Set 12 | northam
# Processing Record 40 of Set 12 | dicabisagan
# Processing Record 41 of Set 12 | oudtshoorn
# Processing Record 42 of Set 12 | tiznit
# Processing Record 43 of Set 12 | rocha
# Processing Record 44 of Set 12 | almaznyy
# Processing Record 45 of Set 12 | aljezur
# Processing Record 46 of Set 12 | ortakoy
# Processing Record 47 of Set 12 | denia
# Processing Record 48 of Set 12 | la libertad
# Processing Record 49 of Set 12 | parfenyevo
# Processing Record 50 of Set 12 | buraydah
# Processing Record 1 of Set 13 | emet
# Processing Record 2 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 13 | san andres
# Processing Record 4 of Set 13 | klaksvik
# Processing Record 5 of Set 13 | scottsburgh
# City not found. Skipping...
# Processing Record 6 of Set 13 | verkhoshizhemye
# Processing Record 7 of Set 13 | emerald
# Processing Record 8 of Set 13 | pouebo
# Processing Record 9 of Set 13 | itapirapua
# Processing Record 10 of Set 13 | dzhusaly
# City not found. Skipping...
# Processing Record 11 of Set 13 | broome
# Processing Record 12 of Set 13 | gold coast
# Processing Record 13 of Set 13 | tabarqah
# City not found. Skipping...
# Processing Record 14 of Set 13 | ambilobe
# Processing Record 15 of Set 13 | cambridge
# Processing Record 16 of Set 13 | rio grande
# Processing Record 17 of Set 13 | xingyi
# Processing Record 18 of Set 13 | temecula
# Processing Record 19 of Set 13 | sorgun
# Processing Record 20 of Set 13 | aktau
# Processing Record 21 of Set 13 | buta
# Processing Record 22 of Set 13 | praxedis guerrero
# Processing Record 23 of Set 13 | pobe
# Processing Record 24 of Set 13 | uglegorsk
# Processing Record 25 of Set 13 | bridlington
# Processing Record 26 of Set 13 | boshnyakovo
# Processing Record 27 of Set 13 | presidencia roque saenz pena
# Processing Record 28 of Set 13 | uruzgan
# Processing Record 29 of Set 13 | lumeje
# Processing Record 30 of Set 13 | ozark
# Processing Record 31 of Set 13 | ketchikan
# Processing Record 32 of Set 13 | eidsvag
# Processing Record 33 of Set 13 | miaray
# Processing Record 34 of Set 13 | malkangiri
# Processing Record 35 of Set 13 | mount kisco
# Processing Record 36 of Set 13 | srednekolymsk
# Processing Record 37 of Set 13 | ngong
# Processing Record 38 of Set 13 | sortland
# Processing Record 39 of Set 13 | mehamn
# Processing Record 40 of Set 13 | kemijarvi
# Processing Record 41 of Set 13 | jishou
# Processing Record 42 of Set 13 | nizwa
# Processing Record 43 of Set 13 | goya
# Processing Record 44 of Set 13 | olinda
# Processing Record 45 of Set 13 | rasra
# Processing Record 46 of Set 13 | kysyl-syr
# Processing Record 47 of Set 13 | mount isa
# Processing Record 48 of Set 13 | sarti
# Processing Record 49 of Set 13 | lincoln
# Processing Record 50 of Set 13 | maraba
# Processing Record 1 of Set 14 | iberia
# Processing Record 2 of Set 14 | luwuk
# Processing Record 3 of Set 14 | xunchang
# Processing Record 4 of Set 14 | nikolsk
# Processing Record 5 of Set 14 | takhtamygda
# Processing Record 6 of Set 14 | hachinohe
# Processing Record 7 of Set 14 | puerto palomas
# Processing Record 8 of Set 14 | lenger
# Processing Record 9 of Set 14 | hervey bay
# Processing Record 10 of Set 14 | gladstone
# Processing Record 11 of Set 14 | greenwood
# Processing Record 12 of Set 14 | buin
# Processing Record 13 of Set 14 | nabire
# Processing Record 14 of Set 14 | satitoa
# City not found. Skipping...
# Processing Record 15 of Set 14 | pochutla
# Processing Record 16 of Set 14 | klyuchi
# Processing Record 17 of Set 14 | thinadhoo
# Processing Record 18 of Set 14 | itarema
# Processing Record 19 of Set 14 | radishchevo
# Processing Record 20 of Set 14 | zavyalovo
# Processing Record 21 of Set 14 | poladpur
# Processing Record 22 of Set 14 | kutahya
# Processing Record 23 of Set 14 | rio tercero
# Processing Record 24 of Set 14 | gisborne
# Processing Record 25 of Set 14 | stromness
# Processing Record 26 of Set 14 | lesnoye
# Processing Record 27 of Set 14 | brookings
# Processing Record 28 of Set 14 | prince george
# Processing Record 29 of Set 14 | lakatoro
# Processing Record 30 of Set 14 | amga
# Processing Record 31 of Set 14 | benguela
# Processing Record 32 of Set 14 | aleksandrov gay
# Processing Record 33 of Set 14 | kushmurun
# Processing Record 34 of Set 14 | barra dos coqueiros
# Processing Record 35 of Set 14 | madingou
# Processing Record 36 of Set 14 | ust-tsilma
# Processing Record 37 of Set 14 | porto novo
# Processing Record 38 of Set 14 | karamken
# City not found. Skipping...
# Processing Record 39 of Set 14 | chegdomyn
# Processing Record 40 of Set 14 | udgir
# Processing Record 41 of Set 14 | bosaso
# Processing Record 42 of Set 14 | gazli
# Processing Record 43 of Set 14 | mikhaylovskoye
# Processing Record 44 of Set 14 | uray
# Processing Record 45 of Set 14 | pozo colorado
# Processing Record 46 of Set 14 | inirida
# Processing Record 47 of Set 14 | norman wells
# Processing Record 48 of Set 14 | jijiga
# Processing Record 49 of Set 14 | porto nacional
# Processing Record 50 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 1 of Set 15 | ravar
# Processing Record 2 of Set 15 | vostok
# Processing Record 3 of Set 15 | joshimath
# Processing Record 4 of Set 15 | sioux lookout
# Processing Record 5 of Set 15 | lichuan
# Processing Record 6 of Set 15 | tommot
# Processing Record 7 of Set 15 | poli
# Processing Record 8 of Set 15 | cam pha
# City not found. Skipping...
# Processing Record 9 of Set 15 | nyurba
# Processing Record 10 of Set 15 | pindiga
# Processing Record 11 of Set 15 | ust-kut
# Processing Record 12 of Set 15 | maloshuyka
# City not found. Skipping...
# Processing Record 13 of Set 15 | imamoglu
# Processing Record 14 of Set 15 | oranjemund
# Processing Record 15 of Set 15 | bejar
# Processing Record 16 of Set 15 | biltine
# Processing Record 17 of Set 15 | campbell river
# Processing Record 18 of Set 15 | roma
# Processing Record 19 of Set 15 | lukang
# Processing Record 20 of Set 15 | urdoma
# Processing Record 21 of Set 15 | igarapava
# Processing Record 22 of Set 15 | mountrath
# Processing Record 23 of Set 15 | nanakuli
# Processing Record 24 of Set 15 | dunedin
# Processing Record 25 of Set 15 | baie-comeau
# Processing Record 26 of Set 15 | pervomayskiy
# Processing Record 27 of Set 15 | coihaique
# Processing Record 28 of Set 15 | lubumbashi
# Processing Record 29 of Set 15 | kikwit
# Processing Record 30 of Set 15 | la foa
# Processing Record 31 of Set 15 | fukue
# Processing Record 32 of Set 15 | nicoya
# Processing Record 33 of Set 15 | sapa
# Processing Record 34 of Set 15 | palmer
# Processing Record 35 of Set 15 | soyo
# Processing Record 36 of Set 15 | selikhino
# Processing Record 37 of Set 15 | hoquiam
# Processing Record 38 of Set 15 | bunia
# Processing Record 39 of Set 15 | yarim
# Processing Record 40 of Set 15 | dalbandin
# Processing Record 41 of Set 15 | makakilo city
# Processing Record 42 of Set 15 | kuldiga
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)

cities_data = city_data

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(cities_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Barrow  71.2906 -156.7887      5.02        85         100
# 1          Rikitea -23.1203 -134.9692     77.29        73         100
# 2        Fairbanks  64.8378 -147.7164     -0.44        68           0
# 3       Baruun-Urt  46.6806  113.2792     -8.59        82           1
# 4   Elizabeth City  36.2946  -76.2511     50.02        55          78
# 5  Bambous Virieux -20.3428   57.7575     79.05        69          40
# 6            Feijo  -8.1642  -70.3536     83.59        81          27
# 7           Tazlau  46.7167   26.4667     25.30        79          31
# 8         Tasiilaq  65.6145  -37.6368     -3.77        62           0
# 9            Lagos   6.5833    3.7500     91.72        43          52
#
#    Wind Speed Country Current Description                 Date
# 0        5.75      US     overcast clouds  2022-12-23 16:52:25
# 1       11.74      PF     overcast clouds  2022-12-23 16:52:25
# 2       16.11      US           clear sky  2022-12-23 16:50:05
# 3        4.45      MN           clear sky  2022-12-23 16:52:26
# 4       23.47      US       broken clouds  2022-12-23 16:52:27
# 5        5.75      MU    scattered clouds  2022-12-23 16:52:27
# 6        2.75      BR    scattered clouds  2022-12-23 16:52:29
# 7        4.41      RO    scattered clouds  2022-12-23 16:52:30
# 8        3.76      GL           clear sky  2022-12-23 16:52:30
# 9        6.96      NG       broken clouds  2022-12-23 16:50:52

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description', 'Date'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
new_column_order =  ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed", "Current Description"]


# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]


# Display sample data
city_data_df
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0            Barrow      US  71.2906 -156.7887      5.02        85
# 1           Rikitea      PF -23.1203 -134.9692     77.29        73
# 2         Fairbanks      US  64.8378 -147.7164     -0.44        68
# 3        Baruun-Urt      MN  46.6806  113.2792     -8.59        82
# 4    Elizabeth City      US  36.2946  -76.2511     50.02        55
# ..              ...     ...      ...       ...       ...       ...
# 674           Bunia      CD   1.5667   30.2500     67.23        81
# 675           Yarim      YE  14.2980   44.3779     53.65        71
# 676       Dalbandin      PK  28.8947   64.4101     46.17        31
# 677   Makakilo City      US  21.3469 -158.0858     73.18        90
# 678         Kuldiga      LV  56.9740   21.9572     37.09        93
#
#      Cloudiness  Wind Speed Current Description
# 0           100        5.75     overcast clouds
# 1           100       11.74     overcast clouds
# 2             0       16.11           clear sky
# 3             1        4.45           clear sky
# 4            78       23.47       broken clouds
# ..          ...         ...                 ...
# 674          98        2.46     overcast clouds
# 675          35        4.07    scattered clouds
# 676           3        7.34           clear sky
# 677          20        4.61          few clouds
# 678         100        4.90     overcast clouds
#
# [679 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function

city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
